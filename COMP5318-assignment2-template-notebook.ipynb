# %% [markdown]
# # COMP4318/5318 Assignment 2: Image Classification

# %% [markdown]
# ### Group number: A2-Group67  , SID1: 520181814 , SID2: 520633597, SID3: ...

# %% [markdown]
# This template notebook includes code to load the  dataset and a skeleton for the main sections that should be included in the notebook. Please stick to this struture for your submitted notebook.
#
# Please focus on making your code clear, with appropriate variable names and whitespace. Include comments and markdown text to aid the readability of your code where relevant. See the specification and marking criteria in the associated specification to guide you when completing your implementation.

# %% [markdown]
# ## Setup and dependencies
# Please use this section to list and set up all your required libraries/dependencies and your plotting environment.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Data loading, exploration, and preprocessing

# %% [markdown]
# Code to load the dataset is provided in the following cell. Please proceed with your data exploration and preprocessing in the remainder of this section.

# %%
# Load the dataset training and test sets as numpy arrays
# assuming Assignment2Data folder is present in the same directory 
# as the notebook
X_train = np.load('Assignment2Data/X_train.npy')
y_train = np.load('Assignment2Data/y_train.npy')
X_test = np.load('Assignment2Data/X_test.npy')
y_test = np.load('Assignment2Data/y_test.npy')

# %% [markdown]
# ### Examples of preprocessed data

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
print("Data type:", X_train.dtype, y_train.dtype)
# Out:
# X_train shape: (32000, 28, 28, 3)
# y_train shape: (32000,)
# X_test shape: (8000, 28, 28, 3)
# y_test shape: (8000,)
# Data type: uint8 uint8

# %%
unique_classes, class_counts = np.unique(y_train, return_counts=True)
print("Class labels:", unique_classes)
# Out:
# Class labels: [0 1 2 3 4 5 6 7 8]

# %%
# Class labels and names
labels, counts = np.unique(y_train, return_counts=True)
class_names = [
    "Adipose",           # 0
    "Background",        # 1
    "Debris",            # 2
    "Lymphocytes",       # 3
    "Mucus",             # 4
    "Smooth muscle",     # 5
    "Normal mucosa",     # 6
    "Cancer stroma",     # 7
    "Adenocarcinoma"     # 8
]

# Print out label counts
for l, c in zip(labels, counts):
    print(f"Label {l} ({class_names[l]}): {c} samples")
# Out:
# Label 0 (Adipose): 3490 samples
# Label 1 (Background): 3431 samples
# Label 2 (Debris): 3505 samples
# Label 3 (Lymphocytes): 3656 samples
# Label 4 (Mucus): 2950 samples
# Label 5 (Smooth muscle): 4290 samples
# Label 6 (Normal mucosa): 2728 samples
# Label 7 (Cancer stroma): 3253 samples
# Label 8 (Adenocarcinoma): 4697 samples

# %%
# Plotting
plt.figure(figsize=(10, 5))
bars = plt.bar(labels, counts, color='skyblue', edgecolor='black')

# Add value labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, height + 100, f'{int(height)}', 
             ha='center', va='bottom', fontsize=9)
plt.xticks(ticks=labels, labels=[f"{l}\n{class_names[l]}" for l in labels], rotation=45, ha='right')
plt.xlabel("Class Labels")
plt.ylabel("Number of Samples")
plt.title("Distribution of Training Labels")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
classes = np.unique(y_train)
num_classes = len(classes)
rows, cols = 3, 3
fig, axs = plt.subplots(rows, cols, figsize=(11, 9))

for i, label in enumerate(classes):
    ax = axs.flat[i]
    sample = X_train[y_train == label][0]
    ax.imshow(sample.astype("uint8"))
    ax.set_title(f'Class {label}: {class_names[label]}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

unique_labels = np.unique(y_train)
num_classes = len(unique_labels)
cols = 3
rows = int(np.ceil(num_classes / cols))

fig, axs = plt.subplots(rows, cols, figsize=(15, 4 * rows))

for i, label in enumerate(unique_labels):
    ax = axs.flat[i]
    class_images = X_train[y_train == label]
    gray_pixels = class_images.mean(axis=(1, 2, 3))  # avg pixel intensity
    ax.hist(gray_pixels, bins=20, alpha=0.7, color='skyblue')
    ax.set_title(f'Class {label}')
    ax.set_xlabel('Avg Pixel Intensity')
    ax.set_ylabel('Frequency')

# Turn off any unused subplots
for i in range(num_classes, len(axs.flat)):
    axs.flat[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Algorithm design and setup

# %% [markdown]
# ### Algorithm of choice from first six weeks of course

# %% [markdown]
# ### Fully connected neural network

# %% [markdown]
# ### Convolutional neural network

# %% [markdown]
# ## 3. Hyperparameter tuning

# %% [markdown]
# ### Algorithm of choice from first six weeks of course

# %% [markdown]
# ### Fully connected neural network

# %% [markdown]
# ### Convolutional neural network

# %% [markdown]
# ## 4. Final models
# In this section, please ensure to include cells to train each model with its best hyperparmater combination independently of the hyperparameter tuning cells, i.e. don't rely on the hyperparameter tuning cells having been run.

# %% [markdown]
# ### Algorithm of choice from first six weeks of course

# %% [markdown]
# ### Fully connected neural network

# %% [markdown]
# ### Convolutional neural network
